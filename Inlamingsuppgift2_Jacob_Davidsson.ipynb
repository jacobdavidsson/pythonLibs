# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
a = np.random.rand(5,10)
print(a)
a[0].dtype
# Out:
# [[0.91745373 0.79112869 0.52165903 0.47341069 0.33352982 0.70625878
#   0.9358579  0.71439558 0.89668018 0.27589944]
#  [0.08561062 0.88267299 0.50578756 0.44356829 0.74559212 0.98615475
#   0.08079098 0.57224999 0.40521003 0.44124905]
#  [0.9801707  0.59022501 0.08384013 0.02209035 0.64591334 0.67198959
#   0.67848255 0.50593208 0.0926757  0.76018176]
#  [0.58858074 0.00628069 0.2687377  0.35094187 0.74243279 0.63583689
#   0.18752684 0.67723088 0.29728466 0.90291602]
#  [0.18324222 0.97087581 0.66223957 0.11627857 0.49089163 0.07256104
#   0.68347132 0.60337079 0.98691235 0.54730869]]
# dtype('float64')

# %%
b = np.random.rand(7,10)
print(b)
b[0].dtype
# Out:
# [[0.9493693  0.48480287 0.00829277 0.41614314 0.89637429 0.367823
#   0.96425227 0.11365377 0.0603055  0.41686083]
#  [0.53490932 0.18573876 0.79051911 0.64603204 0.90396315 0.81643111
#   0.96368702 0.37561752 0.77132076 0.67789901]
#  [0.18544293 0.08999528 0.31634765 0.43965746 0.12188784 0.01210284
#   0.63134694 0.72955378 0.38233691 0.89413105]
#  [0.04368164 0.81543669 0.90255152 0.01949378 0.41083347 0.1326204
#   0.7363168  0.9938526  0.15622935 0.5181746 ]
#  [0.10989274 0.85729749 0.10639056 0.84080014 0.3198395  0.8866443
#   0.25125738 0.68378539 0.51201303 0.52848885]
#  [0.33391241 0.2926112  0.37299141 0.30730784 0.09003223 0.97388282
#   0.31563536 0.28395739 0.17068246 0.11186164]
#  [0.34982928 0.46339611 0.59171168 0.62582861 0.0258935  0.38144792
#   0.90268478 0.32644738 0.18180263 0.32746937]]
# dtype('float64')

# %%
a = a.reshape(-1, 5)
print(a)
# Out:
# [[0.65383332 0.08261491 0.93493136 0.26817336 0.02657881]
#  [0.12854386 0.23558723 0.20531799 0.41547892 0.5196847 ]
#  [0.98462614 0.37262625 0.8543502  0.84229406 0.93683901]
#  [0.08331359 0.40748671 0.42853827 0.60906237 0.50733631]
#  [0.04709103 0.34456448 0.8260522  0.40296091 0.98562626]
#  [0.4203239  0.09889393 0.36814906 0.9910247  0.22805791]
#  [0.74568638 0.27029168 0.74871662 0.17284257 0.44503638]
#  [0.64825235 0.70171884 0.05124554 0.01204432 0.16162487]
#  [0.15449372 0.02070362 0.4740337  0.93683051 0.1402295 ]
#  [0.5767487  0.03963008 0.08246916 0.07848519 0.07997948]]

# %%
b = b.reshape(-1, 5)
print(b)
# Out:
# [[0.93451844 0.84187277 0.54050437 0.30569414 0.05974045]
#  [0.33613792 0.39234657 0.69697818 0.44316818 0.42092181]
#  [0.85996673 0.6435786  0.74491286 0.246404   0.99918934]
#  [0.2194271  0.27470138 0.89198506 0.45078262 0.45283813]
#  [0.50118226 0.04912101 0.11438472 0.39193792 0.84444835]
#  [0.33789337 0.25184949 0.29670121 0.37606446 0.44514342]
#  [0.97715136 0.7607796  0.0548336  0.27345141 0.88525224]
#  [0.03185965 0.70899815 0.61976699 0.92430538 0.97442072]
#  [0.76142498 0.4817983  0.53451784 0.56082571 0.91564958]
#  [0.44088101 0.3912321  0.30300152 0.01854988 0.62297212]
#  [0.58120445 0.7702369  0.69046096 0.99685509 0.32974101]
#  [0.47133428 0.02062341 0.88337005 0.77422301 0.19932271]
#  [0.54041741 0.98232165 0.21297228 0.71646802 0.37601834]
#  [0.03236641 0.3765324  0.20855271 0.36123143 0.42593013]]

# %%
c = np.concatenate((a,b),axis=0)
print(c)
# Out:
# [[0.65383332 0.08261491 0.93493136 0.26817336 0.02657881]
#  [0.12854386 0.23558723 0.20531799 0.41547892 0.5196847 ]
#  [0.98462614 0.37262625 0.8543502  0.84229406 0.93683901]
#  [0.08331359 0.40748671 0.42853827 0.60906237 0.50733631]
#  [0.04709103 0.34456448 0.8260522  0.40296091 0.98562626]
#  [0.4203239  0.09889393 0.36814906 0.9910247  0.22805791]
#  [0.74568638 0.27029168 0.74871662 0.17284257 0.44503638]
#  [0.64825235 0.70171884 0.05124554 0.01204432 0.16162487]
#  [0.15449372 0.02070362 0.4740337  0.93683051 0.1402295 ]
#  [0.5767487  0.03963008 0.08246916 0.07848519 0.07997948]
#  [0.93451844 0.84187277 0.54050437 0.30569414 0.05974045]
#  [0.33613792 0.39234657 0.69697818 0.44316818 0.42092181]
#  [0.85996673 0.6435786  0.74491286 0.246404   0.99918934]
#  [0.2194271  0.27470138 0.89198506 0.45078262 0.45283813]
#  [0.50118226 0.04912101 0.11438472 0.39193792 0.84444835]
#  [0.33789337 0.25184949 0.29670121 0.37606446 0.44514342]
# ...

# %%
print(c[:, [4, 2, 3, 0, 1]])
# Out:
# [[0.02657881 0.93493136 0.26817336 0.65383332 0.08261491]
#  [0.5196847  0.20531799 0.41547892 0.12854386 0.23558723]
#  [0.93683901 0.8543502  0.84229406 0.98462614 0.37262625]
#  [0.50733631 0.42853827 0.60906237 0.08331359 0.40748671]
#  [0.98562626 0.8260522  0.40296091 0.04709103 0.34456448]
#  [0.22805791 0.36814906 0.9910247  0.4203239  0.09889393]
#  [0.44503638 0.74871662 0.17284257 0.74568638 0.27029168]
#  [0.16162487 0.05124554 0.01204432 0.64825235 0.70171884]
#  [0.1402295  0.4740337  0.93683051 0.15449372 0.02070362]
#  [0.07997948 0.08246916 0.07848519 0.5767487  0.03963008]
#  [0.05974045 0.54050437 0.30569414 0.93451844 0.84187277]
#  [0.42092181 0.69697818 0.44316818 0.33613792 0.39234657]
#  [0.99918934 0.74491286 0.246404   0.85996673 0.6435786 ]
#  [0.45283813 0.89198506 0.45078262 0.2194271  0.27470138]
#  [0.84444835 0.11438472 0.39193792 0.50118226 0.04912101]
#  [0.44514342 0.29670121 0.37606446 0.33789337 0.25184949]
# ...

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
data = pd.read_csv('assults.csv')

# %%
data.info()
data.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2020 entries, 0 to 2019
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Index                                  2020 non-null   int64
#  1   Area_unit_2013_code                    2020 non-null   int64
#  2   Area_unit_2013_label                   2020 non-null   object
#  3   Victimisations_calendar_year_2015      2020 non-null   int64
#  4   Population_mid_point_2015              2020 non-null   int64
#  5   Rate_per_10000_population              1603 non-null   object
#  6   Rate_ratio_NZ_average_rate             1603 non-null   float64
#  7   Urban_area_2013_code                   2020 non-null   int64
#  8   Urban_area_2013_label                  2020 non-null   object
#  9   Urban_area_type                        2020 non-null   object
# ...

# %%
data.sort_values('Region_2013_label')
# Out:
#       Index  Area_unit_2013_code     Area_unit_2013_label  \
# 1649   1650               625200  Oceanic-Chatham Islands
# 1705   1706               666669           Bounty Islands
# 1686   1687               614002         Kermadec Islands
# 1615   1616               666670   Oceanic-Snares Islands
# 1656   1657               666673        Antipodes Islands
# ...     ...                  ...                      ...
# 1488   1489               584405                 Orowaiti
# 1789   1790               584936            Arnold Valley
# 1785   1786               584408                Mokihinui
# 978     979               585325                    Haast
# 1406   1407               584934          Greymouth Rural
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 1649                                  0                          0
# 1705                                  0                          0
# ...

# %%
data.sort_values('Population_mid_point_2015', ascending=False)
# Out:
#       Index  Area_unit_2013_code     Area_unit_2013_label  \
# 0         1               514102    Auckland Central West
# 3         4               514103    Auckland Central East
# 27       28               525910           Pukekohe North
# 260     261               505805                    Orewa
# 891     892               509100               Greenhithe
# ...     ...                  ...                      ...
# 1692   1693               625901  Inlet-Dunedin City Bays
# 1693   1694               614601   Inlet-Rangaunu Harbour
# 1694   1695               626000        Inlet-Port Oamaru
# 1695   1696               614602      Inlet-Doubtless Bay
# 1687   1688               625101     Inlet-Port Lyttelton
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# 3                                   375                      13250
# ...

# %%
data.sort_values('Victimisations_calendar_year_2015', ascending=False)
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 1744   1745               614700          Inlet-Whangaroa Harbour
# 1743   1744               617604            Tidal-Manukau Harbour
# 1742   1743               622201            Inlet-Porirua Harbour
# 1741   1742               549902                             Mara
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
data.sort_values('Victimisations_calendar_year_2015', ascending=False).head(10)['Area_unit_2013_label']
# Out:
# 0              Auckland Central West
# 1    Willis Street-Cambridge Terrace
# 2                   Hamilton Central
# 3              Auckland Central East
# 4                   Cathedral Square
# 5               Auckland Harbourside
# 6                    Manukau Central
# 7           Palmerston North Central
# 8                             Kuirau
# 9                   Tauranga Central
# Name: Area_unit_2013_label, dtype: object

# %%
data
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
data = data.drop(columns="Victimisations per population")
data
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
data.insert(5, "Victimisations per population", data['Victimisations_calendar_year_2015'] / data['Population_mid_point_2015'] * 100)

# %%
data
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
data.groupby("Urban_area_2013_label").count()["Area_unit_2013_label"]
# Out:
# Urban_area_2013_label
# Alexandra     1
# Amberley      1
# Arrowtown     1
# Ashburton    11
# Balclutha     1
#              ..
# Whangarei    29
# Whitianga     1
# Winton        1
# Woodend       3
# Woodville     1
# Name: Area_unit_2013_label, Length: 150, dtype: int64

# %%
data.loc[(data["Population_mid_point_2015"] > 1) & (data["Victimisations per population"] == 0)]
# Out:
#       Index  Area_unit_2013_code               Area_unit_2013_label  \
# 1729   1730               626100                Inlet-Milford Sound
# 1730   1731               623900                    Inlet-Ligar Bay
# 1731   1732               625800                Inlet-Otago Harbour
# 1732   1733               619301  Inlets-Thames-Coromandel District
# 1733   1734               612901                          Fiordland
# ...     ...                  ...                                ...
# 2015   2016               506653                          Riverhead
# 2016   2017               610601                           Grasmere
# 2017   2018               536513                     Bethlehem East
# 2018   2019               574302                          Te Kainga
# 2019   2020               527007                      Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 1729                                  0                         10
# ...

# %%
data.isnull().sum()
# Out:
# Index                                      0
# Area_unit_2013_code                        0
# Area_unit_2013_label                       0
# Victimisations_calendar_year_2015          0
# Population_mid_point_2015                  0
# Victimisations per population            116
# Rate_per_10000_population                417
# Rate_ratio_NZ_average_rate               417
# Urban_area_2013_code                       0
# Urban_area_2013_label                      0
# Urban_area_type                            0
# Territorial_authority_area_2013_code       0
# Territorial_authority_area_2013_label      0
# Region_2013_code                           0
# Region_2013_label                          0
# dtype: int64

# %%
data.loc[(data["Rate_per_10000_population"] != "NaN") & (data["Population_mid_point_2015"] > 5000)].sort_values("Rate_per_10000_population", ascending=True).head(10)
# Out:
#      Index  Area_unit_2013_code Area_unit_2013_label  \
# 808    809               562200         Kelvin Grove
# 968    969               501802    Opouteke-Tanekaha
# 967    968               597730                Hinds
# 887    888               528310               Bryant
# 886    887               508411              Glendhu
# 885    886               509400          Mt Victoria
# 807    808               508520            Sunnynook
# 690    691               527009           Huntington
# 36      37               524200        Mangere South
# 63      64               524822        Clendon South
#
#      Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 808                                  7                       7290
# 968                                  5                       5070
# 967                                  5                       5030
# 887                                  6                       6150
# ...

# %%
regions = data.groupby("Region_2013_label").sum()
regions
# Out:
#                            Index  Area_unit_2013_code  \
# Region_2013_label
# Area Outside Region        31979             12115406
# Auckland Region           351263            228136920
# Bay of Plenty Region      116270             69921421
# Canterbury Region         263734            152971702
# Gisborne Region            18953             13134931
# Hawke's Bay Region         80181             46166145
# Manawatu-Wanganui Region  128256             72064146
# Marlborough Region         31022             15140741
# Nelson Region              31980             18146617
# Northland Region           96901             49951297
# Otago Region              156828             79941938
# Southland Region          101248             48378906
# Taranaki Region            75287             36602672
# Tasman Region              36562             17552636
# Waikato Region            214201            112175975
# Wellington Region         221263            121963800
# ...

# %%
regions.insert(4, "Rate_per_10000_population", regions["Victimisations_calendar_year_2015"] / regions["Population_mid_point_2015"] * 10000)
regions
# Out:
#                            Index  Area_unit_2013_code  \
# Region_2013_label
# Area Outside Region        31979             12115406
# Auckland Region           351263            228136920
# Bay of Plenty Region      116270             69921421
# Canterbury Region         263734            152971702
# Gisborne Region            18953             13134931
# Hawke's Bay Region         80181             46166145
# Manawatu-Wanganui Region  128256             72064146
# Marlborough Region         31022             15140741
# Nelson Region              31980             18146617
# Northland Region           96901             49951297
# Otago Region              156828             79941938
# Southland Region          101248             48378906
# Taranaki Region            75287             36602672
# Tasman Region              36562             17552636
# Waikato Region            214201            112175975
# Wellington Region         221263            121963800
# ...

# %%
regions = regions.drop(columns="Victimisations per population")
regions
# Out:
#                            Index  Area_unit_2013_code  \
# Region_2013_label
# Area Outside Region        31979             12115406
# Auckland Region           351263            228136920
# Bay of Plenty Region      116270             69921421
# Canterbury Region         263734            152971702
# Gisborne Region            18953             13134931
# Hawke's Bay Region         80181             46166145
# Manawatu-Wanganui Region  128256             72064146
# Marlborough Region         31022             15140741
# Nelson Region              31980             18146617
# Northland Region           96901             49951297
# Otago Region              156828             79941938
# Southland Region          101248             48378906
# Taranaki Region            75287             36602672
# Tasman Region              36562             17552636
# Waikato Region            214201            112175975
# Wellington Region         221263            121963800
# ...

# %%
regions.insert(4, "Victimisations per population", regions['Victimisations_calendar_year_2015'] / regions['Population_mid_point_2015'] * 100)
regions
# Out:
#                            Index  Area_unit_2013_code  \
# Region_2013_label
# Area Outside Region        31979             12115406
# Auckland Region           351263            228136920
# Bay of Plenty Region      116270             69921421
# Canterbury Region         263734            152971702
# Gisborne Region            18953             13134931
# Hawke's Bay Region         80181             46166145
# Manawatu-Wanganui Region  128256             72064146
# Marlborough Region         31022             15140741
# Nelson Region              31980             18146617
# Northland Region           96901             49951297
# Otago Region              156828             79941938
# Southland Region          101248             48378906
# Taranaki Region            75287             36602672
# Tasman Region              36562             17552636
# Waikato Region            214201            112175975
# Wellington Region         221263            121963800
# ...
